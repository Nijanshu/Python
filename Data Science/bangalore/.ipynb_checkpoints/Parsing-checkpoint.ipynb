# %%
import json

# %%
with open("initialdata.txt", encoding="utf-8") as f:
    data=f.read()

data
chunks= data.split("\n\n")
chunks=[c for c in chunks if len(c)>3]
chunks[10]
# Out:
# '\nig_arbin07\n50 posts\n33 followers\n30 following\naarbinnn\nGamer\n@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️'

# %%
def parse_chunk(chunk):
    chunk=chunk.strip()
    lines=chunk.split("\n")
    username=lines[0]
    posts=int(lines[1].split(" ")[0].replace(",", ""))
    followers=float(lines[2].split(" ")[0].replace(",","").replace("K","").replace("M", ""))
    following=float(lines[3].split(" ")[0].replace(",","").replace("K","").replace("M", ""))

    if("K" in lines[2]):
            followers = int(followers * 1000)
    elif("M" in lines[2]):
            followers = int(followers * 1000000)
    else:
            followers = int(following)
      

    if("K" in lines[3]):
            following = int( following* 1000)
    elif("M" in lines[3]):
            following = int( following* 1000000)
    else:
            following = int(following)


    name=lines[4]
    if(len(lines)> 5):
         type_of_page = lines[5]
         bio = "\n".join(lines[6:])
    else:
         type_of_page = "Unknown"
         bio = "" 

    return {"username": username, "no_of_posts": posts, "no_of_followers": followers,
                "no_of_following": following, "name": name, "type_of_page": type_of_page, "bio": bio}

# %%
all_chunks = [parse_chunk(c) for c in chunks] 

s=json.dumps(all_chunks, indent=4)
print(all_chunks)
with open("data2.json", "w") as f:
    f.write(s)
# Out:
# [{'username': 'intaglobal', 'no_of_posts': '1946', 'no_of_followers': 262, 'no_of_following': 262, 'name': 'INTA', 'type_of_page': 'Nonprofit organization', 'bio': 'The association of ™ professionals.\ninta.campsite.bio'}, {'username': '_anujsinghal', 'no_of_posts': '1785', 'no_of_followers': 681000, 'no_of_following': 248, 'name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}, {'username': 'code_flare', 'no_of_posts': '165', 'no_of_followers': 10, 'no_of_following': 10, 'name': 'The Journey Notebook | Travel | Food Blogger', 'type_of_page': 'Blogger', 'bio': '📍 Exploring places & phases of life 🌍\n.\n🍵 From chai breaks to flight takes ✈️\n.\n💫 Travel | Food | Daily life 🌸\nyoutube.com/@thejourneynotebook?si=Z1lPUAl-cPgHAP_a'}, {'username': 'bangalore_tech_bro', 'no_of_posts': '402', 'no_of_followers': 12500, 'no_of_following': 890, 'name': 'Rahul | HSR Hustler', 'type_of_page': 'Entrepreneur', 'bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}, {'username': 'silkboard_survivor', 'no_of_posts': '55', 'no_of_followers': 50, 'no_of_following': 50, 'name': 'Priya D.', 'type_of_page': 'Public Figure', 'bio': '🚦 Stuck in traffic since 2019\n🌧️ Loving the Bangalore weather, hating the cabs\n🐍 Data Scientist by day, meme maker by night\n📍 ORR\nbit.ly/my-traffic-rants'}, {'username': 'startuphub_blr', 'no_of_posts': '2300', 'no_of_followers': 45000, 'no_of_following': 120, 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}, {'username': 'foodie_in_kora', 'no_of_posts': '890', 'no_of_followers': 400, 'no_of_following': 400, 'name': 'Sneha | Bangalore Eats', 'type_of_page': 'Food & Drink', 'bio': "Aagrah to Truffles 🍔\nExploring Koramangala's cafe culture ☕\nDM for collabs\nhttps://www.google.com/search?q=zomato.com/users/sneha123"}, {'username': 'venture_vikram', 'no_of_posts': '120', 'no_of_followers': 30000, 'no_of_following': 500, 'name': 'Vikram | Angel Investor', 'type_of_page': 'Investor', 'bio': '💸 Helping founders go 0 to 1\nEx-Google, Ex-Amazon\nInvesting in DeepTech & AI\n📍 Indiranagar\nvikram.vc/pitch-deck'}, {'username': 'python_meetup_blr', 'no_of_posts': '60', 'no_of_followers': 10, 'no_of_following': 10, 'name': 'PyBangalore Community', 'type_of_page': 'Community', 'bio': '🐍 Weekly meetups for Pythonistas\n📍 Cubbon Park | Sundays 4 PM\nCoding + Coffee + Community\nhttps://www.google.com/search?q=meetup.com/pybangalore'}, {'username': 'indiranagar_gossip', 'no_of_posts': '300', 'no_of_followers': 20, 'no_of_following': 20, 'name': 'Indiranagar Spy', 'type_of_page': 'Personal Blog', 'bio': 'Not just about 100ft Road 🤫\nSpilling tea on the best brunches and worst landlords\nBengaluru\nhttps://www.google.com/search?q=medium.com/%40indiranagarspy'}, {'username': 'ig_arbin07', 'no_of_posts': '50', 'no_of_followers': 30, 'no_of_following': 30, 'name': 'aarbinnn', 'type_of_page': 'Gamer', 'bio': '@dumb.arbin\n🎮: Banana『juice (IGL🥷)\nGamer never die, they just respawn🙂\u200d↔️'}, {'username': '7iiuliiu', 'no_of_posts': '1', 'no_of_followers': 166, 'no_of_following': 166, 'name': '︎𝐄︎ ♡︎.', 'type_of_page': 'Unknown', 'bio': ''}, {'username': 'katiasales2220', 'no_of_posts': '107', 'no_of_followers': 1401, 'no_of_following': 1401, 'name': 'Katia Sales', 'type_of_page': 'Alfabetização e Reforço Escolar', 'bio': 'Ensino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio'}]

# %% [markdown]
# ### Max Posts and Max followers

# %%
max=0
for chunk in all_chunks:
    if(max<chunk['no_of_posts']):
        max=chunk['no_of_posts']
        max_post_chunk= chunk

print(max_post_chunk)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 3
#       1 max=0
#       2 for chunk in all_chunks:
# ----> 3     if(max<chunk['no_of_posts']):
#       4         max=chunk['no_of_posts']
#       5         max_post_chunk= chunk
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
p
